# %%
#HiveContext
from pyspark.sql import HiveContext
hiveContext = HiveContext(sc)
hiveContext.sql("show schemas").show()

# %%
#functions for sqlContext and hiveContext are the same

# %%
tmp_list = [{'name':'vivek','number':100}]
df = spark.createDataFrame(tmp_list)
df.show()

# %%
hiveContext.registerDataFrameAsTable(df,"myTable")

# %%
hiveContext.sql("show tables").show()
hiveContext.sql("select * from myTable").show()
